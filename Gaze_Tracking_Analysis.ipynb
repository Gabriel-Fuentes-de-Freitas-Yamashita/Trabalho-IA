# %% [markdown]
# # Gaze Tracking Analysis - Prova de Conceito em Python Notebook
#
# Este notebook Python tem o objetivo de:
#
# 1.  **Demonstrar** a instalação e o uso básico das bibliotecas `mediapipe` e `opencv-python` para processamento de imagens estáticas ou de um pequeno vídeo.
# 2.  **Validar** a lógica de `GazeAnalyzer` (dentro de `utils/gaze_analyzer.py`) com dados controlados.
# 3.  **Visualizar** as matrizes de rotação e translação (pose da cabeça) para entender o cálculo do olhar antes de integrá-lo ao Streamlit.
#
# **Próximos Passos:** Execute as células com as bibliotecas e importe a classe `GazeAnalyzer` para testar.
